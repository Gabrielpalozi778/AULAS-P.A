# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrielpalozi778/AULAS-P.A/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dólar

# %%
dólar = 4.98
peso_argentino = 0.0059
Dólar_Australiano	=	3.293
Dólar_Canadense	=	3.695
Franco_Suíço	=	5.664
Dólar_Comercial	=	4.979
Dólar_Turismo	=	4.999
Euro = 5.448
Libra_Esterlina	=	6.357
Iene =	0.0478

reais = float(input("digite a quantidade em reais:"))

resultado = reais * dólar

resultado2 = reais * peso_argentino

resultado3 = reais * Dólar_Australiano

resultado4 = reais * Dólar_Canadense

resultado5 = reais * Franco_Suíço

resultado6 = reais * Dólar_Comercial

resultado7 = reais * Dólar_Turismo

resultado8 = reais * Euro

resultado9 = reais * Libra_Esterlina

resultado10 = reais * Iene


print(resultado)

print("------------------------------------------------------------------------")

print(resultado2)

print("------------------------------------------------------------------------")

print(resultado3)

print("------------------------------------------------------------------------")

print(resultado4)

print("------------------------------------------------------------------------")

print(resultado5)

print("------------------------------------------------------------------------")

print(resultado6)

print("------------------------------------------------------------------------")

print(resultado7)

print("------------------------------------------------------------------------")

print(resultado8)

print("------------------------------------------------------------------------")

print(resultado9)

print("------------------------------------------------------------------------")

print(resultado10)

print("------------------------------------------------------------------------")
# Out:
# digite a quantidade em reais:7
# 34.86
# ------------------------------------------------------------------------
# 0.041299999999999996
# ------------------------------------------------------------------------
# 23.051000000000002
# ------------------------------------------------------------------------
# 25.865
# ------------------------------------------------------------------------
# 39.647999999999996
# ------------------------------------------------------------------------
# 34.853
# ------------------------------------------------------------------------
# 34.992999999999995
# ------------------------------------------------------------------------
# 38.136
# ------------------------------------------------------------------------
# 44.499
# ------------------------------------------------------------------------
# 0.3346
# ------------------------------------------------------------------------

# %% [markdown]
# soma dos quadrados

# %%
n1 = float(input("digite o número 1:"))
n2 = float(input("digite o número 2:"))
n3 = float(input("digite o número 3:"))
n4 = float(input("digite o número 4:"))

resultado = (n1*n1) + (n2*n2) + (n3*n3) + (n4*n4)

print(resultado)
# Out:
# digite o número 1:2
# digite o número 2:4
# digite o número 3:5
# digite o número 4:6
# 81.0

# %% [markdown]
# preço da peça

# %% [markdown]
# ![Capturar.PNG](data:image/png;base64,...![Capturar.PNG](data:image/png;base64,...![Capturar.PNG](data:image/png;base64,...)))carro

# %%
preço = float(input("digite o preço:"))
quant = float(input("digite a quant:"))

resultado = preço * quant

resultado_definitivo = (resultado / 100) * 5

print("-------------------------------------------------------------------------")

print("eis qui a quantidade vendida")

print(resultado_definitivo)

print("-------------------------------------------------------------------------")

print("eis aqui a cotação")

print(resultado)
# Out:
# digite o preço:2.5
# digite a quant:200
# -------------------------------------------------------------------------
# eis qui a quantidade vendida
# 25.0
# -------------------------------------------------------------------------
# eis aqui a cotação
# 500.0

# %% [markdown]
# #
# PESTE QUALQUER

# %%
#coleta de valores do maluco que ira escrever
distancia = float(input("digite a distancia percorrida:"))

qtde_horas = int(input("digite a quantidade de horas:"))

qtde_min = int(input("digite a quantidade de minutos:"))
# Out:
# digite a distancia percorrida:150
# digite a quantidade de horas:1
# digite a quantidade de minutos:13

# %%
#processsamento

tempo_total = qtde_horas + (qtde_min/60)

# %%
#resposta

print ("----------------------------------------------------------------------")

print (tempo_total)

print ("este é o respectivo tempo total")

print ("----------------------------------------------------------------------")
# Out:
# ----------------------------------------------------------------------
# 1.2166666666666668
# este é o respectivo tempo total
# ----------------------------------------------------------------------

# %%
#arredondamento

round (tempo_total)
# Out:
# 1

# %%
#coleta de valores do maluco que ira escrever
distancia = float(input("digite a distancia percorrida:"))

qtde_horas = int(input("digite a quantidade de horas:"))

qtde_min = int(input("digite a quantidade de minutos:"))




#processsamento

tempo_total = qtde_horas + (qtde_min/60)




#resposta

print ("----------------------------------------------------------------------")

print (tempo_total)

print ("este é o respectivo tempo total")

print ("----------------------------------------------------------------------")






#arredondamento

round (tempo_total)

print ("este é o respectivo arrendondamento")
# Out:
# digite a distancia percorrida:150
# digite a quantidade de horas:42
# digite a quantidade de minutos:447
# ----------------------------------------------------------------------
# 49.45
# este é o respectivo tempo total
# ----------------------------------------------------------------------
# este é o respectivo arrendondamento

# %% [markdown]
# ![image.png](data:image/png;base64,...)
